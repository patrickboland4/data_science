# %%
from IPython.display import Image
from IPython.core.display import HTML 
PATH = "/Users/patrickboland4/p_code/data_science/images/"

# %% [markdown]
# **What is the primary goal of SVMs?**

# %% [markdown]
# - Classify data, recognize patterns
# - Given a set of test data, SVMs classify new data into one category or the other

# %% [markdown]
# **Are SVMs for Supervised or Unsupervised Learning?**

# %% [markdown]
# - Supervised learning

# %% [markdown]
# **Are SVMs used for Classification or Regression?**

# %% [markdown]
# - Both

# %% [markdown]
# **Which lines in the image below could help us determine our binary classifier?**

# %%
Image(filename = PATH + "svm0.png", height=350, width=350)

# %% [markdown]
# - Each line

# %% [markdown]
# **What is the goal of a binary classifier?**

# %% [markdown]
# - Maximize the margin between two classes

# %%
Image(filename = PATH + "svm1.png", height=350, width=350)

# %% [markdown]
# **In the image below, what are the circled points which touch the outlines of our hyperplane referred to as?**

# %%
Image(filename = PATH + "svm2.png", height=350, width=350)

# %% [markdown]
# - These points represent Support Vectors

# %% [markdown]
# **In the image below (left), will we have success with the linear approach above?**

# %%
Image(filename = PATH + "kernel0.png", height=550, width=550)

# %% [markdown]
# - No because we will need to operate in 3 dimensional space to classify these data

# %% [markdown]
# **What is the kernel trick and what is a relevant application? **

# %% [markdown]
# - The kernel trick allows us to perform binary classification in higher dimensions. It is computationally inexpensive
# - A relevant application would be separating the points in the image below (right). The output of the classifier in 3 dimensional space can be viewed on the left.

# %%
Image(filename = PATH + "kernel1.png", height=550, width=550)
