# %%
from IPython.display import Image
from IPython.core.display import HTML 
PATH = "/Users/patrickboland4/p_code/data_science/images/"

# %% [markdown]
# ### Overview

# %% [markdown]
# - **Logistic Regression is a method used for** ...
#
#
#     - Classification
#
# - **What are some practical examples of Logistic Regression**
#
#
#     - Binary Classification
#         - Spam vs Ham
#         - Loan Default
#         - Disease Diagnosis
#
# - **Describe the output of the sigmoid function, how does it differ from the ouput of the linear function?**
#
#
#         - Logistic Model uses the Sigmoid function which outputs values between 0 and 1
#         - Linear Model values can be < 0 or > 1

# %%
Image(filename = PATH + "sigmoid3.png", height=550, width=550)

# %% [markdown]
# - **What is a method for evaluating Logistic Regression?**
#
#
#     - Confusion Matrix

# %%
Image(filename = PATH + "confusion_matrix.png", height=550, width=550)

# %% [markdown]
# - **What is a Type 1 Error? What is a Type 2 Error**
#
#
#     - Type 1 Error -> False Positive
#     - Type 2 Error -> False Negative
